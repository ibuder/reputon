# %%
import pandas as pd
import sklearn as skl
import sklearn.metrics
import numpy as np
import googlemaps

import sys
sys.path = sys.path + ['..']  # Use main code from subdirectory
import get_airbnb_data
import settings
import db
from learning import *

# %%
client = googlemaps.Client(settings.google_api_key)

# %%
g = client.geocode('Fresno, CA')
bounds = g[0]['geometry']['bounds']  # Get bounding box
lat = (bounds['southwest']['lat'], bounds['northeast']['lat'])
lon = (bounds['southwest']['lng'], bounds['northeast']['lng'])
get_airbnb_data.populate_db_raster(lat, lon, step_km=1)
# I removed all lines reporting no listings from the output below
# Out:
# 1 listings at 36.814876384207246, -119.90083310534519 page 1
# 1 listings at 36.82385958916061, -119.90083310534519 page 1
# 1 listings at 36.760977154487044, -119.88961647379358 page 1
# 1 listings at 36.76996035944041, -119.88961647379358 page 1
# 1 listings at 36.82385958916061, -119.88961647379358 page 1
# 1 listings at 36.760977154487044, -119.87839984224198 page 1
# 1 listings at 36.76996035944041, -119.87839984224198 page 1
# 1 listings at 36.814876384207246, -119.86718321069037 page 1
# 1 listings at 36.82385958916061, -119.86718321069037 page 1
# 1 listings at 36.814876384207246, -119.85596657913877 page 1
# 1 listings at 36.82385958916061, -119.85596657913877 page 1
# 1 listings at 36.83284279411398, -119.85596657913877 page 1
# 1 listings at 36.841825999067346, -119.85596657913877 page 1
# 1 listings at 36.76996035944041, -119.84474994758716 page 1
# 1 listings at 36.83284279411398, -119.84474994758716 page 1
# 1 listings at 36.841825999067346, -119.84474994758716 page 1
# ...

# %%
g = client.geocode('Milwaukee, WI')
bounds = g[0]['geometry']['bounds']
lat = (bounds['southwest']['lat'], bounds['northeast']['lat'])
lon = (bounds['southwest']['lng'], bounds['northeast']['lng'])
get_airbnb_data.populate_db_raster(lat, lon, step_km=1)
# Out:
# 1 listings at 43.03759746439377, -88.070876 page 1
# 1 listings at 43.04658066934714, -88.070876 page 1
# 3 listings at 43.019631054487036, -88.05858142683627 page 1
# 3 listings at 43.0286142594404, -88.05858142683627 page 1
# 1 listings at 43.04658066934714, -88.05858142683627 page 1
# 1 listings at 42.9208158, -88.04628685367254 page 1
# 1 listings at 42.92979900495337, -88.04628685367254 page 1
# 3 listings at 43.019631054487036, -88.04628685367254 page 1
# 3 listings at 43.0286142594404, -88.04628685367254 page 1
# 1 listings at 43.09149669411397, -88.04628685367254 page 1
# 1 listings at 43.10047989906734, -88.04628685367254 page 1
# 1 listings at 42.9208158, -88.03399228050881 page 1
# 1 listings at 43.0555638743005, -88.03399228050881 page 1
# 1 listings at 43.09149669411397, -88.03399228050881 page 1
# 1 listings at 43.10047989906734, -88.03399228050881 page 1
# 1 listings at 43.03759746439377, -88.02169770734508 page 1
# ...
